# %%
# Do not edit this input-output processing section
import pandas as pd
import numpy as np

df = pd.read_csv('dummy_district_data.csv')
input_state = input().strip()

# Write your code here
df['Literacy Rate'] = df['Literate'] / df['Population']
state_df = df[df['State'].str.upper() == input_state.upper()]
ser_out = state_df.loc[state_df['Literacy Rate'].idxmax()]

# Do not edit this output processing section
