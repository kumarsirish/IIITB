# %% [markdown]
# Importing the Pandas library

# %%
import pandas as pd

# %% [markdown]
# You can load data into Google Colaboratory in several ways. Note that you need to connect to a runtime before you can load data into Colab. The simplest way is to drag-and-drop your data into the 'Files' section on the toolbar on the left. If you do so, you can consider the file to belong to your root folder; you can access the file without any path prefix.

# %%
# Once you have dragged-and-dropped the file into the 'Files' section, you can access it, with pandas, for instance
df_matches = pd.read_csv('matches_data.csv')
df_matches.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-94c3cda4a55d> in <cell line: 2>()
#       1 # Once you have dragged-and-dropped the file into the 'Files' section, you can access it, with pandas, for instance
# ----> 2 df_matches = pd.read_csv('matches_data.csv')
#       3 df_matches.head()
#
# ...

# %%
df_matches.tail(n = 7)

# %%
df_matches.info()

# %%
df_matches.describe()

# %% [markdown]
# You can also mount your drive and then access files from your drive by running the following code:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# You can now import data from your drive

# %%
df_google_stock_prices = pd.read_csv('/content/drive/MyDrive/datasets/GOOGL_prices.csv')
df_google_stock_prices.head()

# %% [markdown]
# You can unmount your drive in-code using the following:

# %%
drive.flush_and_unmount()

# %% [markdown]
# You can also directly import data from a link as follows:

# %%
# !wget 'https://openbudgetsindia.org/dataset/ceb4b91a-b4bc-4b9e-808a-2e8a5692ed0d/resource/ac990b22-79b0-41e4-9347-90ddb5db1ee9/download/budget-at-a-glance-updated1---budget-at-a-glance-updated1.csv'

# %%
df_budget_data = pd.read_csv('budget-at-a-glance-updated1---budget-at-a-glance-updated1.csv')
df_budget_data.head()

# %%
df_budget_data.tail()

# %%
df_budget_data.info()

# %%
df_budget_data.describe()
