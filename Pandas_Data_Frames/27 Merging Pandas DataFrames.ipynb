# %% [markdown]
# Let's import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Let's consider two datasets, the first containing the volume of Google stocks on certain days, and the second, the prices

# %%
df_volume = pd.read_csv('GOOGL_volume.csv')
df_prices = pd.read_csv('GOOGL_prices.csv')

# %%
df_volume
# Out:
#         Date    Volume
# 0   1/3/2006  13137450
# 1   1/4/2006  15292353
# 2   1/5/2006  10815661
# 3   1/9/2006  12795837
# 4  1/10/2006   9104719

# %%
df_prices
# Out:
#        Date    Open    High     Low   Close
# 0  1/3/2006  211.47  218.05  209.32  217.83
# 1  1/4/2006  222.17  224.70  220.09  222.84
# 2  1/5/2006  223.22  226.00  220.97  225.85
# 3  1/6/2006  228.66  235.49  226.85  233.06
# 4  1/9/2006  233.44  236.94  230.70  233.68

# %% [markdown]
# Merging two DataFrames

# %% [markdown]
# We want to merge (join) the DataFrames so we can have all the information in a single table. There are various different types of merges. While merging we need to provide a key, which is usually a column that is common between the two DataFrames. We will use the date as the key (`on = 'Date'`) in our case

# %%
df_inner_join = pd.merge(df_volume, df_prices, on = 'Date', how = 'inner')  # default join is 'inner'
df_inner_join
# Out:
#        Date    Volume    Open    High     Low   Close
# 0  1/3/2006  13137450  211.47  218.05  209.32  217.83
# 1  1/4/2006  15292353  222.17  224.70  220.09  222.84
# 2  1/5/2006  10815661  223.22  226.00  220.97  225.85
# 3  1/9/2006  12795837  233.44  236.94  230.70  233.68

# %%
df_outer_join = pd.merge(df_volume, df_prices, on = 'Date', how = 'outer')
df_outer_join
# Out:
#         Date      Volume    Open    High     Low   Close
# 0  1/10/2006   9104719.0     NaN     NaN     NaN     NaN
# 1   1/3/2006  13137450.0  211.47  218.05  209.32  217.83
# 2   1/4/2006  15292353.0  222.17  224.70  220.09  222.84
# 3   1/5/2006  10815661.0  223.22  226.00  220.97  225.85
# 4   1/6/2006         NaN  228.66  235.49  226.85  233.06
# 5   1/9/2006  12795837.0  233.44  236.94  230.70  233.68

# %%
df_left_join = pd.merge(df_volume, df_prices, on = 'Date', how = 'left')
df_left_join
# Out:
#         Date    Volume    Open    High     Low   Close
# 0   1/3/2006  13137450  211.47  218.05  209.32  217.83
# 1   1/4/2006  15292353  222.17  224.70  220.09  222.84
# 2   1/5/2006  10815661  223.22  226.00  220.97  225.85
# 3   1/9/2006  12795837  233.44  236.94  230.70  233.68
# 4  1/10/2006   9104719     NaN     NaN     NaN     NaN

# %%
df_right_join = pd.merge(df_volume, df_prices, on = 'Date', how = 'right')
df_right_join
# Out:
#        Date      Volume    Open    High     Low   Close
# 0  1/3/2006  13137450.0  211.47  218.05  209.32  217.83
# 1  1/4/2006  15292353.0  222.17  224.70  220.09  222.84
# 2  1/5/2006  10815661.0  223.22  226.00  220.97  225.85
# 3  1/6/2006         NaN  228.66  235.49  226.85  233.06
# 4  1/9/2006  12795837.0  233.44  236.94  230.70  233.68

# %%
df_cross_join = pd.merge(df_volume, df_prices, how = 'cross')  # cross joins do not accept an 'on' argument
df_cross_join
# Out:
#        Date_x    Volume    Date_y    Open    High     Low   Close
# 0    1/3/2006  13137450  1/3/2006  211.47  218.05  209.32  217.83
# 1    1/3/2006  13137450  1/4/2006  222.17  224.70  220.09  222.84
# 2    1/3/2006  13137450  1/5/2006  223.22  226.00  220.97  225.85
# 3    1/3/2006  13137450  1/6/2006  228.66  235.49  226.85  233.06
# 4    1/3/2006  13137450  1/9/2006  233.44  236.94  230.70  233.68
# 5    1/4/2006  15292353  1/3/2006  211.47  218.05  209.32  217.83
# 6    1/4/2006  15292353  1/4/2006  222.17  224.70  220.09  222.84
# 7    1/4/2006  15292353  1/5/2006  223.22  226.00  220.97  225.85
# 8    1/4/2006  15292353  1/6/2006  228.66  235.49  226.85  233.06
# 9    1/4/2006  15292353  1/9/2006  233.44  236.94  230.70  233.68
# 10   1/5/2006  10815661  1/3/2006  211.47  218.05  209.32  217.83
# 11   1/5/2006  10815661  1/4/2006  222.17  224.70  220.09  222.84
# 12   1/5/2006  10815661  1/5/2006  223.22  226.00  220.97  225.85
# 13   1/5/2006  10815661  1/6/2006  228.66  235.49  226.85  233.06
# 14   1/5/2006  10815661  1/9/2006  233.44  236.94  230.70  233.68
# 15   1/9/2006  12795837  1/3/2006  211.47  218.05  209.32  217.83
# 16   1/9/2006  12795837  1/4/2006  222.17  224.70  220.09  222.84
# 17   1/9/2006  12795837  1/5/2006  223.22  226.00  220.97  225.85
# 18   1/9/2006  12795837  1/6/2006  228.66  235.49  226.85  233.06
# 19   1/9/2006  12795837  1/9/2006  233.44  236.94  230.70  233.68
# 20  1/10/2006   9104719  1/3/2006  211.47  218.05  209.32  217.83
# 21  1/10/2006   9104719  1/4/2006  222.17  224.70  220.09  222.84
# 22  1/10/2006   9104719  1/5/2006  223.22  226.00  220.97  225.85
# 23  1/10/2006   9104719  1/6/2006  228.66  235.49  226.85  233.06
# 24  1/10/2006   9104719  1/9/2006  233.44  236.94  230.70  233.68

# %% [markdown]
# DataFrames can be concatenated along a certain axis with `pd.concat()`

# %%
df_concat_rows = pd.concat([df_volume, df_prices], axis = 0)  # concatenates one DataFrame below the other
df_concat_rows
# Out:
#         Date      Volume    Open    High     Low   Close
# 0   1/3/2006  13137450.0     NaN     NaN     NaN     NaN
# 1   1/4/2006  15292353.0     NaN     NaN     NaN     NaN
# 2   1/5/2006  10815661.0     NaN     NaN     NaN     NaN
# 3   1/9/2006  12795837.0     NaN     NaN     NaN     NaN
# 4  1/10/2006   9104719.0     NaN     NaN     NaN     NaN
# 0   1/3/2006         NaN  211.47  218.05  209.32  217.83
# 1   1/4/2006         NaN  222.17  224.70  220.09  222.84
# 2   1/5/2006         NaN  223.22  226.00  220.97  225.85
# 3   1/6/2006         NaN  228.66  235.49  226.85  233.06
# 4   1/9/2006         NaN  233.44  236.94  230.70  233.68

# %%
df_concat_cols = pd.concat([df_volume, df_prices], axis = 1)  # concatenates DataFrames side-by-side
df_concat_cols
# Out:
#         Date    Volume      Date    Open    High     Low   Close
# 0   1/3/2006  13137450  1/3/2006  211.47  218.05  209.32  217.83
# 1   1/4/2006  15292353  1/4/2006  222.17  224.70  220.09  222.84
# 2   1/5/2006  10815661  1/5/2006  223.22  226.00  220.97  225.85
# 3   1/9/2006  12795837  1/6/2006  228.66  235.49  226.85  233.06
# 4  1/10/2006   9104719  1/9/2006  233.44  236.94  230.70  233.68
